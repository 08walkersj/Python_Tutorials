# %% [markdown]
# # How to add new data to a pre existing dataframe

# %% [markdown]
# First we need to import the necessary packages

# %%
import vaex as vx
import numpy as np

# %% [markdown]
# # Method 1
#
# - The first method we will look at is very similar to pandas
# - We will first load up a file to use as an example and to practice loading files

# %%
path= 'test_vaex.hdf5'
data= vx.open(path)

# %% [markdown]
# We create a new column by places the string for the new columns name inside square brackets and assigning it data that is the same length as the existing dataframe

# %%
data['new_column']= np.random.uniform(size=len(data))

# %% [markdown]
# This is the same way you can add a new key to a dictionary or a new column to a pandas dataframe, so hopefully it is a little familiar

# %% [markdown]
# # Method 2
# - This next method will show us how to add new rows of data
# - We will create a test dataframe for this example to make you familiar with creating dataframes in vaex

# %% [markdown]
# This code creates an array of datetimes which increase by 1 minute each time

# %%
times= [np.datetime64('2001-01-01')+ np.timedelta64(i, 'm') for i in range(0, 1000, 1)]
times
# Out:
# [numpy.datetime64('2001-01-01T00:00'),
#  numpy.datetime64('2001-01-01T00:01'),
#  numpy.datetime64('2001-01-01T00:02'),
#  numpy.datetime64('2001-01-01T00:03'),
#  numpy.datetime64('2001-01-01T00:04'),
#  numpy.datetime64('2001-01-01T00:05'),
#  numpy.datetime64('2001-01-01T00:06'),
#  numpy.datetime64('2001-01-01T00:07'),
#  numpy.datetime64('2001-01-01T00:08'),
#  numpy.datetime64('2001-01-01T00:09'),
#  numpy.datetime64('2001-01-01T00:10'),
#  numpy.datetime64('2001-01-01T00:11'),
#  numpy.datetime64('2001-01-01T00:12'),
#  numpy.datetime64('2001-01-01T00:13'),
#  numpy.datetime64('2001-01-01T00:14'),
#  numpy.datetime64('2001-01-01T00:15'),
#  numpy.datetime64('2001-01-01T00:16'),
#  numpy.datetime64('2001-01-01T00:17'),
#  numpy.datetime64('2001-01-01T00:18'),
#  numpy.datetime64('2001-01-01T00:19'),
#  numpy.datetime64('2001-01-01T00:20'),
#  numpy.datetime64('2001-01-01T00:21'),
#  numpy.datetime64('2001-01-01T00:22'),
#  numpy.datetime64('2001-01-01T00:23'),
#  numpy.datetime64('2001-01-01T00:24'),
#  numpy.datetime64('2001-01-01T00:25'),
#  numpy.datetime64('2001-01-01T00:26'),
#  numpy.datetime64('2001-01-01T00:27'),
#  numpy.datetime64('2001-01-01T00:28'),
#  numpy.datetime64('2001-01-01T00:29'),
#  numpy.datetime64('2001-01-01T00:30'),
#  numpy.datetime64('2001-01-01T00:31'),
#  numpy.datetime64('2001-01-01T00:32'),
#  numpy.datetime64('2001-01-01T00:33'),
#  numpy.datetime64('2001-01-01T00:34'),
#  numpy.datetime64('2001-01-01T00:35'),
#  numpy.datetime64('2001-01-01T00:36'),
#  numpy.datetime64('2001-01-01T00:37'),
#  numpy.datetime64('2001-01-01T00:38'),
#  numpy.datetime64('2001-01-01T00:39'),
#  numpy.datetime64('2001-01-01T00:40'),
#  numpy.datetime64('2001-01-01T00:41'),
#  numpy.datetime64('2001-01-01T00:42'),
#  numpy.datetime64('2001-01-01T00:43'),
#  numpy.datetime64('2001-01-01T00:44'),
#  numpy.datetime64('2001-01-01T00:45'),
#  numpy.datetime64('2001-01-01T00:46'),
#  numpy.datetime64('2001-01-01T00:47'),
#  numpy.datetime64('2001-01-01T00:48'),
#  numpy.datetime64('2001-01-01T00:49'),
#  numpy.datetime64('2001-01-01T00:50'),
#  numpy.datetime64('2001-01-01T00:51'),
#  numpy.datetime64('2001-01-01T00:52'),
#  numpy.datetime64('2001-01-01T00:53'),
#  numpy.datetime64('2001-01-01T00:54'),
#  numpy.datetime64('2001-01-01T00:55'),
#  numpy.datetime64('2001-01-01T00:56'),
#  numpy.datetime64('2001-01-01T00:57'),
#  numpy.datetime64('2001-01-01T00:58'),
#  numpy.datetime64('2001-01-01T00:59'),
#  numpy.datetime64('2001-01-01T01:00'),
#  numpy.datetime64('2001-01-01T01:01'),
#  numpy.datetime64('2001-01-01T01:02'),
#  numpy.datetime64('2001-01-01T01:03'),
#  numpy.datetime64('2001-01-01T01:04'),
#  numpy.datetime64('2001-01-01T01:05'),
#  numpy.datetime64('2001-01-01T01:06'),
#  numpy.datetime64('2001-01-01T01:07'),
#  numpy.datetime64('2001-01-01T01:08'),
#  numpy.datetime64('2001-01-01T01:09'),
#  numpy.datetime64('2001-01-01T01:10'),
#  numpy.datetime64('2001-01-01T01:11'),
#  numpy.datetime64('2001-01-01T01:12'),
#  numpy.datetime64('2001-01-01T01:13'),
#  numpy.datetime64('2001-01-01T01:14'),
#  numpy.datetime64('2001-01-01T01:15'),
#  numpy.datetime64('2001-01-01T01:16'),
#  numpy.datetime64('2001-01-01T01:17'),
#  numpy.datetime64('2001-01-01T01:18'),
#  numpy.datetime64('2001-01-01T01:19'),
#  numpy.datetime64('2001-01-01T01:20'),
#  numpy.datetime64('2001-01-01T01:21'),
#  numpy.datetime64('2001-01-01T01:22'),
#  numpy.datetime64('2001-01-01T01:23'),
#  numpy.datetime64('2001-01-01T01:24'),
#  numpy.datetime64('2001-01-01T01:25'),
#  numpy.datetime64('2001-01-01T01:26'),
#  numpy.datetime64('2001-01-01T01:27'),
#  numpy.datetime64('2001-01-01T01:28'),
#  numpy.datetime64('2001-01-01T01:29'),
#  numpy.datetime64('2001-01-01T01:30'),
#  numpy.datetime64('2001-01-01T01:31'),
#  numpy.datetime64('2001-01-01T01:32'),
#  numpy.datetime64('2001-01-01T01:33'),
#  numpy.datetime64('2001-01-01T01:34'),
#  numpy.datetime64('2001-01-01T01:35'),
#  numpy.datetime64('2001-01-01T01:36'),
#  numpy.datetime64('2001-01-01T01:37'),
#  numpy.datetime64('2001-01-01T01:38'),
#  numpy.datetime64('2001-01-01T01:39'),
#  numpy.datetime64('2001-01-01T01:40'),
#  numpy.datetime64('2001-01-01T01:41'),
#  numpy.datetime64('2001-01-01T01:42'),
#  numpy.datetime64('2001-01-01T01:43'),
#  numpy.datetime64('2001-01-01T01:44'),
#  numpy.datetime64('2001-01-01T01:45'),
#  numpy.datetime64('2001-01-01T01:46'),
#  numpy.datetime64('2001-01-01T01:47'),
#  numpy.datetime64('2001-01-01T01:48'),
#  numpy.datetime64('2001-01-01T01:49'),
#  numpy.datetime64('2001-01-01T01:50'),
#  numpy.datetime64('2001-01-01T01:51'),
#  numpy.datetime64('2001-01-01T01:52'),
#  numpy.datetime64('2001-01-01T01:53'),
#  numpy.datetime64('2001-01-01T01:54'),
#  numpy.datetime64('2001-01-01T01:55'),
#  numpy.datetime64('2001-01-01T01:56'),
#  numpy.datetime64('2001-01-01T01:57'),
#  numpy.datetime64('2001-01-01T01:58'),
#  numpy.datetime64('2001-01-01T01:59'),
#  numpy.datetime64('2001-01-01T02:00'),
#  numpy.datetime64('2001-01-01T02:01'),
#  numpy.datetime64('2001-01-01T02:02'),
#  numpy.datetime64('2001-01-01T02:03'),
#  numpy.datetime64('2001-01-01T02:04'),
#  numpy.datetime64('2001-01-01T02:05'),
#  numpy.datetime64('2001-01-01T02:06'),
#  numpy.datetime64('2001-01-01T02:07'),
#  numpy.datetime64('2001-01-01T02:08'),
#  numpy.datetime64('2001-01-01T02:09'),
#  numpy.datetime64('2001-01-01T02:10'),
#  numpy.datetime64('2001-01-01T02:11'),
#  numpy.datetime64('2001-01-01T02:12'),
#  numpy.datetime64('2001-01-01T02:13'),
#  numpy.datetime64('2001-01-01T02:14'),
#  numpy.datetime64('2001-01-01T02:15'),
#  numpy.datetime64('2001-01-01T02:16'),
#  numpy.datetime64('2001-01-01T02:17'),
#  numpy.datetime64('2001-01-01T02:18'),
#  numpy.datetime64('2001-01-01T02:19'),
#  numpy.datetime64('2001-01-01T02:20'),
#  numpy.datetime64('2001-01-01T02:21'),
#  numpy.datetime64('2001-01-01T02:22'),
#  numpy.datetime64('2001-01-01T02:23'),
#  numpy.datetime64('2001-01-01T02:24'),
#  numpy.datetime64('2001-01-01T02:25'),
#  numpy.datetime64('2001-01-01T02:26'),
#  numpy.datetime64('2001-01-01T02:27'),
#  numpy.datetime64('2001-01-01T02:28'),
#  numpy.datetime64('2001-01-01T02:29'),
#  numpy.datetime64('2001-01-01T02:30'),
#  numpy.datetime64('2001-01-01T02:31'),
#  numpy.datetime64('2001-01-01T02:32'),
#  numpy.datetime64('2001-01-01T02:33'),
#  numpy.datetime64('2001-01-01T02:34'),
#  numpy.datetime64('2001-01-01T02:35'),
#  numpy.datetime64('2001-01-01T02:36'),
#  numpy.datetime64('2001-01-01T02:37'),
#  numpy.datetime64('2001-01-01T02:38'),
#  numpy.datetime64('2001-01-01T02:39'),
#  numpy.datetime64('2001-01-01T02:40'),
#  numpy.datetime64('2001-01-01T02:41'),
#  numpy.datetime64('2001-01-01T02:42'),
#  numpy.datetime64('2001-01-01T02:43'),
#  numpy.datetime64('2001-01-01T02:44'),
#  numpy.datetime64('2001-01-01T02:45'),
#  numpy.datetime64('2001-01-01T02:46'),
#  numpy.datetime64('2001-01-01T02:47'),
#  numpy.datetime64('2001-01-01T02:48'),
#  numpy.datetime64('2001-01-01T02:49'),
#  numpy.datetime64('2001-01-01T02:50'),
#  numpy.datetime64('2001-01-01T02:51'),
#  numpy.datetime64('2001-01-01T02:52'),
#  numpy.datetime64('2001-01-01T02:53'),
#  numpy.datetime64('2001-01-01T02:54'),
#  numpy.datetime64('2001-01-01T02:55'),
#  numpy.datetime64('2001-01-01T02:56'),
#  numpy.datetime64('2001-01-01T02:57'),
#  numpy.datetime64('2001-01-01T02:58'),
#  numpy.datetime64('2001-01-01T02:59'),
#  numpy.datetime64('2001-01-01T03:00'),
#  numpy.datetime64('2001-01-01T03:01'),
#  numpy.datetime64('2001-01-01T03:02'),
#  numpy.datetime64('2001-01-01T03:03'),
#  numpy.datetime64('2001-01-01T03:04'),
#  numpy.datetime64('2001-01-01T03:05'),
#  numpy.datetime64('2001-01-01T03:06'),
#  numpy.datetime64('2001-01-01T03:07'),
#  numpy.datetime64('2001-01-01T03:08'),
#  numpy.datetime64('2001-01-01T03:09'),
#  numpy.datetime64('2001-01-01T03:10'),
#  numpy.datetime64('2001-01-01T03:11'),
#  numpy.datetime64('2001-01-01T03:12'),
#  numpy.datetime64('2001-01-01T03:13'),
#  numpy.datetime64('2001-01-01T03:14'),
#  numpy.datetime64('2001-01-01T03:15'),
#  numpy.datetime64('2001-01-01T03:16'),
#  numpy.datetime64('2001-01-01T03:17'),
#  numpy.datetime64('2001-01-01T03:18'),
#  numpy.datetime64('2001-01-01T03:19'),
#  numpy.datetime64('2001-01-01T03:20'),
#  numpy.datetime64('2001-01-01T03:21'),
#  numpy.datetime64('2001-01-01T03:22'),
#  numpy.datetime64('2001-01-01T03:23'),
#  numpy.datetime64('2001-01-01T03:24'),
#  numpy.datetime64('2001-01-01T03:25'),
#  numpy.datetime64('2001-01-01T03:26'),
#  numpy.datetime64('2001-01-01T03:27'),
#  numpy.datetime64('2001-01-01T03:28'),
#  numpy.datetime64('2001-01-01T03:29'),
#  numpy.datetime64('2001-01-01T03:30'),
#  numpy.datetime64('2001-01-01T03:31'),
#  numpy.datetime64('2001-01-01T03:32'),
#  numpy.datetime64('2001-01-01T03:33'),
#  numpy.datetime64('2001-01-01T03:34'),
#  numpy.datetime64('2001-01-01T03:35'),
#  numpy.datetime64('2001-01-01T03:36'),
#  numpy.datetime64('2001-01-01T03:37'),
#  numpy.datetime64('2001-01-01T03:38'),
#  numpy.datetime64('2001-01-01T03:39'),
#  numpy.datetime64('2001-01-01T03:40'),
#  numpy.datetime64('2001-01-01T03:41'),
#  numpy.datetime64('2001-01-01T03:42'),
#  numpy.datetime64('2001-01-01T03:43'),
#  numpy.datetime64('2001-01-01T03:44'),
#  numpy.datetime64('2001-01-01T03:45'),
#  numpy.datetime64('2001-01-01T03:46'),
#  numpy.datetime64('2001-01-01T03:47'),
#  numpy.datetime64('2001-01-01T03:48'),
#  numpy.datetime64('2001-01-01T03:49'),
#  numpy.datetime64('2001-01-01T03:50'),
#  numpy.datetime64('2001-01-01T03:51'),
#  numpy.datetime64('2001-01-01T03:52'),
#  numpy.datetime64('2001-01-01T03:53'),
#  numpy.datetime64('2001-01-01T03:54'),
#  numpy.datetime64('2001-01-01T03:55'),
#  numpy.datetime64('2001-01-01T03:56'),
#  numpy.datetime64('2001-01-01T03:57'),
#  numpy.datetime64('2001-01-01T03:58'),
#  numpy.datetime64('2001-01-01T03:59'),
#  numpy.datetime64('2001-01-01T04:00'),
#  numpy.datetime64('2001-01-01T04:01'),
#  numpy.datetime64('2001-01-01T04:02'),
#  numpy.datetime64('2001-01-01T04:03'),
#  numpy.datetime64('2001-01-01T04:04'),
#  numpy.datetime64('2001-01-01T04:05'),
#  numpy.datetime64('2001-01-01T04:06'),
#  numpy.datetime64('2001-01-01T04:07'),
#  numpy.datetime64('2001-01-01T04:08'),
#  numpy.datetime64('2001-01-01T04:09'),
#  numpy.datetime64('2001-01-01T04:10'),
#  numpy.datetime64('2001-01-01T04:11'),
#  numpy.datetime64('2001-01-01T04:12'),
#  numpy.datetime64('2001-01-01T04:13'),
#  numpy.datetime64('2001-01-01T04:14'),
#  numpy.datetime64('2001-01-01T04:15'),
#  numpy.datetime64('2001-01-01T04:16'),
#  numpy.datetime64('2001-01-01T04:17'),
#  numpy.datetime64('2001-01-01T04:18'),
#  numpy.datetime64('2001-01-01T04:19'),
#  numpy.datetime64('2001-01-01T04:20'),
#  numpy.datetime64('2001-01-01T04:21'),
#  numpy.datetime64('2001-01-01T04:22'),
#  numpy.datetime64('2001-01-01T04:23'),
#  numpy.datetime64('2001-01-01T04:24'),
#  numpy.datetime64('2001-01-01T04:25'),
#  numpy.datetime64('2001-01-01T04:26'),
#  numpy.datetime64('2001-01-01T04:27'),
#  numpy.datetime64('2001-01-01T04:28'),
#  numpy.datetime64('2001-01-01T04:29'),
#  numpy.datetime64('2001-01-01T04:30'),
#  numpy.datetime64('2001-01-01T04:31'),
#  numpy.datetime64('2001-01-01T04:32'),
#  numpy.datetime64('2001-01-01T04:33'),
#  numpy.datetime64('2001-01-01T04:34'),
#  numpy.datetime64('2001-01-01T04:35'),
#  numpy.datetime64('2001-01-01T04:36'),
#  numpy.datetime64('2001-01-01T04:37'),
#  numpy.datetime64('2001-01-01T04:38'),
#  numpy.datetime64('2001-01-01T04:39'),
#  numpy.datetime64('2001-01-01T04:40'),
#  numpy.datetime64('2001-01-01T04:41'),
#  numpy.datetime64('2001-01-01T04:42'),
#  numpy.datetime64('2001-01-01T04:43'),
#  numpy.datetime64('2001-01-01T04:44'),
#  numpy.datetime64('2001-01-01T04:45'),
#  numpy.datetime64('2001-01-01T04:46'),
#  numpy.datetime64('2001-01-01T04:47'),
#  numpy.datetime64('2001-01-01T04:48'),
#  numpy.datetime64('2001-01-01T04:49'),
#  numpy.datetime64('2001-01-01T04:50'),
#  numpy.datetime64('2001-01-01T04:51'),
#  numpy.datetime64('2001-01-01T04:52'),
#  numpy.datetime64('2001-01-01T04:53'),
#  numpy.datetime64('2001-01-01T04:54'),
#  numpy.datetime64('2001-01-01T04:55'),
#  numpy.datetime64('2001-01-01T04:56'),
#  numpy.datetime64('2001-01-01T04:57'),
#  numpy.datetime64('2001-01-01T04:58'),
#  numpy.datetime64('2001-01-01T04:59'),
#  numpy.datetime64('2001-01-01T05:00'),
#  numpy.datetime64('2001-01-01T05:01'),
#  numpy.datetime64('2001-01-01T05:02'),
#  numpy.datetime64('2001-01-01T05:03'),
#  numpy.datetime64('2001-01-01T05:04'),
#  numpy.datetime64('2001-01-01T05:05'),
#  numpy.datetime64('2001-01-01T05:06'),
#  numpy.datetime64('2001-01-01T05:07'),
#  numpy.datetime64('2001-01-01T05:08'),
#  numpy.datetime64('2001-01-01T05:09'),
#  numpy.datetime64('2001-01-01T05:10'),
#  numpy.datetime64('2001-01-01T05:11'),
#  numpy.datetime64('2001-01-01T05:12'),
#  numpy.datetime64('2001-01-01T05:13'),
#  numpy.datetime64('2001-01-01T05:14'),
#  numpy.datetime64('2001-01-01T05:15'),
#  numpy.datetime64('2001-01-01T05:16'),
#  numpy.datetime64('2001-01-01T05:17'),
#  numpy.datetime64('2001-01-01T05:18'),
#  numpy.datetime64('2001-01-01T05:19'),
#  numpy.datetime64('2001-01-01T05:20'),
#  numpy.datetime64('2001-01-01T05:21'),
#  numpy.datetime64('2001-01-01T05:22'),
#  numpy.datetime64('2001-01-01T05:23'),
#  numpy.datetime64('2001-01-01T05:24'),
#  numpy.datetime64('2001-01-01T05:25'),
#  numpy.datetime64('2001-01-01T05:26'),
#  numpy.datetime64('2001-01-01T05:27'),
#  numpy.datetime64('2001-01-01T05:28'),
#  numpy.datetime64('2001-01-01T05:29'),
#  numpy.datetime64('2001-01-01T05:30'),
#  numpy.datetime64('2001-01-01T05:31'),
#  numpy.datetime64('2001-01-01T05:32'),
#  numpy.datetime64('2001-01-01T05:33'),
#  numpy.datetime64('2001-01-01T05:34'),
#  numpy.datetime64('2001-01-01T05:35'),
#  numpy.datetime64('2001-01-01T05:36'),
#  numpy.datetime64('2001-01-01T05:37'),
#  numpy.datetime64('2001-01-01T05:38'),
#  numpy.datetime64('2001-01-01T05:39'),
#  numpy.datetime64('2001-01-01T05:40'),
#  numpy.datetime64('2001-01-01T05:41'),
#  numpy.datetime64('2001-01-01T05:42'),
#  numpy.datetime64('2001-01-01T05:43'),
#  numpy.datetime64('2001-01-01T05:44'),
#  numpy.datetime64('2001-01-01T05:45'),
#  numpy.datetime64('2001-01-01T05:46'),
#  numpy.datetime64('2001-01-01T05:47'),
#  numpy.datetime64('2001-01-01T05:48'),
#  numpy.datetime64('2001-01-01T05:49'),
#  numpy.datetime64('2001-01-01T05:50'),
#  numpy.datetime64('2001-01-01T05:51'),
#  numpy.datetime64('2001-01-01T05:52'),
#  numpy.datetime64('2001-01-01T05:53'),
#  numpy.datetime64('2001-01-01T05:54'),
#  numpy.datetime64('2001-01-01T05:55'),
#  numpy.datetime64('2001-01-01T05:56'),
#  numpy.datetime64('2001-01-01T05:57'),
#  numpy.datetime64('2001-01-01T05:58'),
#  numpy.datetime64('2001-01-01T05:59'),
#  numpy.datetime64('2001-01-01T06:00'),
#  numpy.datetime64('2001-01-01T06:01'),
#  numpy.datetime64('2001-01-01T06:02'),
#  numpy.datetime64('2001-01-01T06:03'),
#  numpy.datetime64('2001-01-01T06:04'),
#  numpy.datetime64('2001-01-01T06:05'),
#  numpy.datetime64('2001-01-01T06:06'),
#  numpy.datetime64('2001-01-01T06:07'),
#  numpy.datetime64('2001-01-01T06:08'),
#  numpy.datetime64('2001-01-01T06:09'),
#  numpy.datetime64('2001-01-01T06:10'),
#  numpy.datetime64('2001-01-01T06:11'),
#  numpy.datetime64('2001-01-01T06:12'),
#  numpy.datetime64('2001-01-01T06:13'),
#  numpy.datetime64('2001-01-01T06:14'),
#  numpy.datetime64('2001-01-01T06:15'),
#  numpy.datetime64('2001-01-01T06:16'),
#  numpy.datetime64('2001-01-01T06:17'),
#  numpy.datetime64('2001-01-01T06:18'),
#  numpy.datetime64('2001-01-01T06:19'),
#  numpy.datetime64('2001-01-01T06:20'),
#  numpy.datetime64('2001-01-01T06:21'),
#  numpy.datetime64('2001-01-01T06:22'),
#  numpy.datetime64('2001-01-01T06:23'),
#  numpy.datetime64('2001-01-01T06:24'),
#  numpy.datetime64('2001-01-01T06:25'),
#  numpy.datetime64('2001-01-01T06:26'),
#  numpy.datetime64('2001-01-01T06:27'),
#  numpy.datetime64('2001-01-01T06:28'),
#  numpy.datetime64('2001-01-01T06:29'),
#  numpy.datetime64('2001-01-01T06:30'),
#  numpy.datetime64('2001-01-01T06:31'),
#  numpy.datetime64('2001-01-01T06:32'),
#  numpy.datetime64('2001-01-01T06:33'),
#  numpy.datetime64('2001-01-01T06:34'),
#  numpy.datetime64('2001-01-01T06:35'),
#  numpy.datetime64('2001-01-01T06:36'),
#  numpy.datetime64('2001-01-01T06:37'),
#  numpy.datetime64('2001-01-01T06:38'),
#  numpy.datetime64('2001-01-01T06:39'),
#  numpy.datetime64('2001-01-01T06:40'),
#  numpy.datetime64('2001-01-01T06:41'),
#  numpy.datetime64('2001-01-01T06:42'),
#  numpy.datetime64('2001-01-01T06:43'),
#  numpy.datetime64('2001-01-01T06:44'),
#  numpy.datetime64('2001-01-01T06:45'),
#  numpy.datetime64('2001-01-01T06:46'),
#  numpy.datetime64('2001-01-01T06:47'),
#  numpy.datetime64('2001-01-01T06:48'),
#  numpy.datetime64('2001-01-01T06:49'),
#  numpy.datetime64('2001-01-01T06:50'),
#  numpy.datetime64('2001-01-01T06:51'),
#  numpy.datetime64('2001-01-01T06:52'),
#  numpy.datetime64('2001-01-01T06:53'),
#  numpy.datetime64('2001-01-01T06:54'),
#  numpy.datetime64('2001-01-01T06:55'),
#  numpy.datetime64('2001-01-01T06:56'),
#  numpy.datetime64('2001-01-01T06:57'),
#  numpy.datetime64('2001-01-01T06:58'),
#  numpy.datetime64('2001-01-01T06:59'),
#  numpy.datetime64('2001-01-01T07:00'),
#  numpy.datetime64('2001-01-01T07:01'),
#  numpy.datetime64('2001-01-01T07:02'),
#  numpy.datetime64('2001-01-01T07:03'),
#  numpy.datetime64('2001-01-01T07:04'),
#  numpy.datetime64('2001-01-01T07:05'),
#  numpy.datetime64('2001-01-01T07:06'),
#  numpy.datetime64('2001-01-01T07:07'),
#  numpy.datetime64('2001-01-01T07:08'),
#  numpy.datetime64('2001-01-01T07:09'),
#  numpy.datetime64('2001-01-01T07:10'),
#  numpy.datetime64('2001-01-01T07:11'),
#  numpy.datetime64('2001-01-01T07:12'),
#  numpy.datetime64('2001-01-01T07:13'),
#  numpy.datetime64('2001-01-01T07:14'),
#  numpy.datetime64('2001-01-01T07:15'),
#  numpy.datetime64('2001-01-01T07:16'),
#  numpy.datetime64('2001-01-01T07:17'),
#  numpy.datetime64('2001-01-01T07:18'),
#  numpy.datetime64('2001-01-01T07:19'),
#  numpy.datetime64('2001-01-01T07:20'),
#  numpy.datetime64('2001-01-01T07:21'),
#  numpy.datetime64('2001-01-01T07:22'),
#  numpy.datetime64('2001-01-01T07:23'),
#  numpy.datetime64('2001-01-01T07:24'),
#  numpy.datetime64('2001-01-01T07:25'),
#  numpy.datetime64('2001-01-01T07:26'),
#  numpy.datetime64('2001-01-01T07:27'),
#  numpy.datetime64('2001-01-01T07:28'),
#  numpy.datetime64('2001-01-01T07:29'),
#  numpy.datetime64('2001-01-01T07:30'),
#  numpy.datetime64('2001-01-01T07:31'),
#  numpy.datetime64('2001-01-01T07:32'),
#  numpy.datetime64('2001-01-01T07:33'),
#  numpy.datetime64('2001-01-01T07:34'),
#  numpy.datetime64('2001-01-01T07:35'),
#  numpy.datetime64('2001-01-01T07:36'),
#  numpy.datetime64('2001-01-01T07:37'),
#  numpy.datetime64('2001-01-01T07:38'),
#  numpy.datetime64('2001-01-01T07:39'),
#  numpy.datetime64('2001-01-01T07:40'),
#  numpy.datetime64('2001-01-01T07:41'),
#  numpy.datetime64('2001-01-01T07:42'),
#  numpy.datetime64('2001-01-01T07:43'),
#  numpy.datetime64('2001-01-01T07:44'),
#  numpy.datetime64('2001-01-01T07:45'),
#  numpy.datetime64('2001-01-01T07:46'),
#  numpy.datetime64('2001-01-01T07:47'),
#  numpy.datetime64('2001-01-01T07:48'),
#  numpy.datetime64('2001-01-01T07:49'),
#  numpy.datetime64('2001-01-01T07:50'),
#  numpy.datetime64('2001-01-01T07:51'),
#  numpy.datetime64('2001-01-01T07:52'),
#  numpy.datetime64('2001-01-01T07:53'),
#  numpy.datetime64('2001-01-01T07:54'),
#  numpy.datetime64('2001-01-01T07:55'),
#  numpy.datetime64('2001-01-01T07:56'),
#  numpy.datetime64('2001-01-01T07:57'),
#  numpy.datetime64('2001-01-01T07:58'),
#  numpy.datetime64('2001-01-01T07:59'),
#  numpy.datetime64('2001-01-01T08:00'),
#  numpy.datetime64('2001-01-01T08:01'),
#  numpy.datetime64('2001-01-01T08:02'),
#  numpy.datetime64('2001-01-01T08:03'),
#  numpy.datetime64('2001-01-01T08:04'),
#  numpy.datetime64('2001-01-01T08:05'),
#  numpy.datetime64('2001-01-01T08:06'),
#  numpy.datetime64('2001-01-01T08:07'),
#  numpy.datetime64('2001-01-01T08:08'),
#  numpy.datetime64('2001-01-01T08:09'),
#  numpy.datetime64('2001-01-01T08:10'),
#  numpy.datetime64('2001-01-01T08:11'),
#  numpy.datetime64('2001-01-01T08:12'),
#  numpy.datetime64('2001-01-01T08:13'),
#  numpy.datetime64('2001-01-01T08:14'),
#  numpy.datetime64('2001-01-01T08:15'),
#  numpy.datetime64('2001-01-01T08:16'),
#  numpy.datetime64('2001-01-01T08:17'),
#  numpy.datetime64('2001-01-01T08:18'),
#  numpy.datetime64('2001-01-01T08:19'),
#  numpy.datetime64('2001-01-01T08:20'),
#  numpy.datetime64('2001-01-01T08:21'),
#  numpy.datetime64('2001-01-01T08:22'),
#  numpy.datetime64('2001-01-01T08:23'),
#  numpy.datetime64('2001-01-01T08:24'),
#  numpy.datetime64('2001-01-01T08:25'),
#  numpy.datetime64('2001-01-01T08:26'),
#  numpy.datetime64('2001-01-01T08:27'),
#  numpy.datetime64('2001-01-01T08:28'),
#  numpy.datetime64('2001-01-01T08:29'),
#  numpy.datetime64('2001-01-01T08:30'),
#  numpy.datetime64('2001-01-01T08:31'),
#  numpy.datetime64('2001-01-01T08:32'),
#  numpy.datetime64('2001-01-01T08:33'),
#  numpy.datetime64('2001-01-01T08:34'),
#  numpy.datetime64('2001-01-01T08:35'),
#  numpy.datetime64('2001-01-01T08:36'),
#  numpy.datetime64('2001-01-01T08:37'),
#  numpy.datetime64('2001-01-01T08:38'),
#  numpy.datetime64('2001-01-01T08:39'),
#  numpy.datetime64('2001-01-01T08:40'),
#  numpy.datetime64('2001-01-01T08:41'),
#  numpy.datetime64('2001-01-01T08:42'),
#  numpy.datetime64('2001-01-01T08:43'),
#  numpy.datetime64('2001-01-01T08:44'),
#  numpy.datetime64('2001-01-01T08:45'),
#  numpy.datetime64('2001-01-01T08:46'),
#  numpy.datetime64('2001-01-01T08:47'),
#  numpy.datetime64('2001-01-01T08:48'),
#  numpy.datetime64('2001-01-01T08:49'),
#  numpy.datetime64('2001-01-01T08:50'),
#  numpy.datetime64('2001-01-01T08:51'),
#  numpy.datetime64('2001-01-01T08:52'),
#  numpy.datetime64('2001-01-01T08:53'),
#  numpy.datetime64('2001-01-01T08:54'),
#  numpy.datetime64('2001-01-01T08:55'),
#  numpy.datetime64('2001-01-01T08:56'),
#  numpy.datetime64('2001-01-01T08:57'),
#  numpy.datetime64('2001-01-01T08:58'),
#  numpy.datetime64('2001-01-01T08:59'),
#  numpy.datetime64('2001-01-01T09:00'),
#  numpy.datetime64('2001-01-01T09:01'),
#  numpy.datetime64('2001-01-01T09:02'),
#  numpy.datetime64('2001-01-01T09:03'),
#  numpy.datetime64('2001-01-01T09:04'),
#  numpy.datetime64('2001-01-01T09:05'),
#  numpy.datetime64('2001-01-01T09:06'),
#  numpy.datetime64('2001-01-01T09:07'),
#  numpy.datetime64('2001-01-01T09:08'),
#  numpy.datetime64('2001-01-01T09:09'),
#  numpy.datetime64('2001-01-01T09:10'),
#  numpy.datetime64('2001-01-01T09:11'),
#  numpy.datetime64('2001-01-01T09:12'),
#  numpy.datetime64('2001-01-01T09:13'),
#  numpy.datetime64('2001-01-01T09:14'),
#  numpy.datetime64('2001-01-01T09:15'),
#  numpy.datetime64('2001-01-01T09:16'),
#  numpy.datetime64('2001-01-01T09:17'),
#  numpy.datetime64('2001-01-01T09:18'),
#  numpy.datetime64('2001-01-01T09:19'),
#  numpy.datetime64('2001-01-01T09:20'),
#  numpy.datetime64('2001-01-01T09:21'),
#  numpy.datetime64('2001-01-01T09:22'),
#  numpy.datetime64('2001-01-01T09:23'),
#  numpy.datetime64('2001-01-01T09:24'),
#  numpy.datetime64('2001-01-01T09:25'),
#  numpy.datetime64('2001-01-01T09:26'),
#  numpy.datetime64('2001-01-01T09:27'),
#  numpy.datetime64('2001-01-01T09:28'),
#  numpy.datetime64('2001-01-01T09:29'),
#  numpy.datetime64('2001-01-01T09:30'),
#  numpy.datetime64('2001-01-01T09:31'),
#  numpy.datetime64('2001-01-01T09:32'),
#  numpy.datetime64('2001-01-01T09:33'),
#  numpy.datetime64('2001-01-01T09:34'),
#  numpy.datetime64('2001-01-01T09:35'),
#  numpy.datetime64('2001-01-01T09:36'),
#  numpy.datetime64('2001-01-01T09:37'),
#  numpy.datetime64('2001-01-01T09:38'),
#  numpy.datetime64('2001-01-01T09:39'),
#  numpy.datetime64('2001-01-01T09:40'),
#  numpy.datetime64('2001-01-01T09:41'),
#  numpy.datetime64('2001-01-01T09:42'),
#  numpy.datetime64('2001-01-01T09:43'),
#  numpy.datetime64('2001-01-01T09:44'),
#  numpy.datetime64('2001-01-01T09:45'),
#  numpy.datetime64('2001-01-01T09:46'),
#  numpy.datetime64('2001-01-01T09:47'),
#  numpy.datetime64('2001-01-01T09:48'),
#  numpy.datetime64('2001-01-01T09:49'),
#  numpy.datetime64('2001-01-01T09:50'),
#  numpy.datetime64('2001-01-01T09:51'),
#  numpy.datetime64('2001-01-01T09:52'),
#  numpy.datetime64('2001-01-01T09:53'),
#  numpy.datetime64('2001-01-01T09:54'),
#  numpy.datetime64('2001-01-01T09:55'),
#  numpy.datetime64('2001-01-01T09:56'),
#  numpy.datetime64('2001-01-01T09:57'),
#  numpy.datetime64('2001-01-01T09:58'),
#  numpy.datetime64('2001-01-01T09:59'),
#  numpy.datetime64('2001-01-01T10:00'),
#  numpy.datetime64('2001-01-01T10:01'),
#  numpy.datetime64('2001-01-01T10:02'),
#  numpy.datetime64('2001-01-01T10:03'),
#  numpy.datetime64('2001-01-01T10:04'),
#  numpy.datetime64('2001-01-01T10:05'),
#  numpy.datetime64('2001-01-01T10:06'),
#  numpy.datetime64('2001-01-01T10:07'),
#  numpy.datetime64('2001-01-01T10:08'),
#  numpy.datetime64('2001-01-01T10:09'),
#  numpy.datetime64('2001-01-01T10:10'),
#  numpy.datetime64('2001-01-01T10:11'),
#  numpy.datetime64('2001-01-01T10:12'),
#  numpy.datetime64('2001-01-01T10:13'),
#  numpy.datetime64('2001-01-01T10:14'),
#  numpy.datetime64('2001-01-01T10:15'),
#  numpy.datetime64('2001-01-01T10:16'),
#  numpy.datetime64('2001-01-01T10:17'),
#  numpy.datetime64('2001-01-01T10:18'),
#  numpy.datetime64('2001-01-01T10:19'),
#  numpy.datetime64('2001-01-01T10:20'),
#  numpy.datetime64('2001-01-01T10:21'),
#  numpy.datetime64('2001-01-01T10:22'),
#  numpy.datetime64('2001-01-01T10:23'),
#  numpy.datetime64('2001-01-01T10:24'),
#  numpy.datetime64('2001-01-01T10:25'),
#  numpy.datetime64('2001-01-01T10:26'),
#  numpy.datetime64('2001-01-01T10:27'),
#  numpy.datetime64('2001-01-01T10:28'),
#  numpy.datetime64('2001-01-01T10:29'),
#  numpy.datetime64('2001-01-01T10:30'),
#  numpy.datetime64('2001-01-01T10:31'),
#  numpy.datetime64('2001-01-01T10:32'),
#  numpy.datetime64('2001-01-01T10:33'),
#  numpy.datetime64('2001-01-01T10:34'),
#  numpy.datetime64('2001-01-01T10:35'),
#  numpy.datetime64('2001-01-01T10:36'),
#  numpy.datetime64('2001-01-01T10:37'),
#  numpy.datetime64('2001-01-01T10:38'),
#  numpy.datetime64('2001-01-01T10:39'),
#  numpy.datetime64('2001-01-01T10:40'),
#  numpy.datetime64('2001-01-01T10:41'),
#  numpy.datetime64('2001-01-01T10:42'),
#  numpy.datetime64('2001-01-01T10:43'),
#  numpy.datetime64('2001-01-01T10:44'),
#  numpy.datetime64('2001-01-01T10:45'),
#  numpy.datetime64('2001-01-01T10:46'),
#  numpy.datetime64('2001-01-01T10:47'),
#  numpy.datetime64('2001-01-01T10:48'),
#  numpy.datetime64('2001-01-01T10:49'),
#  numpy.datetime64('2001-01-01T10:50'),
#  numpy.datetime64('2001-01-01T10:51'),
#  numpy.datetime64('2001-01-01T10:52'),
#  numpy.datetime64('2001-01-01T10:53'),
#  numpy.datetime64('2001-01-01T10:54'),
#  numpy.datetime64('2001-01-01T10:55'),
#  numpy.datetime64('2001-01-01T10:56'),
#  numpy.datetime64('2001-01-01T10:57'),
#  numpy.datetime64('2001-01-01T10:58'),
#  numpy.datetime64('2001-01-01T10:59'),
#  numpy.datetime64('2001-01-01T11:00'),
#  numpy.datetime64('2001-01-01T11:01'),
#  numpy.datetime64('2001-01-01T11:02'),
#  numpy.datetime64('2001-01-01T11:03'),
#  numpy.datetime64('2001-01-01T11:04'),
#  numpy.datetime64('2001-01-01T11:05'),
#  numpy.datetime64('2001-01-01T11:06'),
#  numpy.datetime64('2001-01-01T11:07'),
#  numpy.datetime64('2001-01-01T11:08'),
#  numpy.datetime64('2001-01-01T11:09'),
#  numpy.datetime64('2001-01-01T11:10'),
#  numpy.datetime64('2001-01-01T11:11'),
#  numpy.datetime64('2001-01-01T11:12'),
#  numpy.datetime64('2001-01-01T11:13'),
#  numpy.datetime64('2001-01-01T11:14'),
#  numpy.datetime64('2001-01-01T11:15'),
#  numpy.datetime64('2001-01-01T11:16'),
#  numpy.datetime64('2001-01-01T11:17'),
#  numpy.datetime64('2001-01-01T11:18'),
#  numpy.datetime64('2001-01-01T11:19'),
#  numpy.datetime64('2001-01-01T11:20'),
#  numpy.datetime64('2001-01-01T11:21'),
#  numpy.datetime64('2001-01-01T11:22'),
#  numpy.datetime64('2001-01-01T11:23'),
#  numpy.datetime64('2001-01-01T11:24'),
#  numpy.datetime64('2001-01-01T11:25'),
#  numpy.datetime64('2001-01-01T11:26'),
#  numpy.datetime64('2001-01-01T11:27'),
#  numpy.datetime64('2001-01-01T11:28'),
#  numpy.datetime64('2001-01-01T11:29'),
#  numpy.datetime64('2001-01-01T11:30'),
#  numpy.datetime64('2001-01-01T11:31'),
#  numpy.datetime64('2001-01-01T11:32'),
#  numpy.datetime64('2001-01-01T11:33'),
#  numpy.datetime64('2001-01-01T11:34'),
#  numpy.datetime64('2001-01-01T11:35'),
#  numpy.datetime64('2001-01-01T11:36'),
#  numpy.datetime64('2001-01-01T11:37'),
#  numpy.datetime64('2001-01-01T11:38'),
#  numpy.datetime64('2001-01-01T11:39'),
#  numpy.datetime64('2001-01-01T11:40'),
#  numpy.datetime64('2001-01-01T11:41'),
#  numpy.datetime64('2001-01-01T11:42'),
#  numpy.datetime64('2001-01-01T11:43'),
#  numpy.datetime64('2001-01-01T11:44'),
#  numpy.datetime64('2001-01-01T11:45'),
#  numpy.datetime64('2001-01-01T11:46'),
#  numpy.datetime64('2001-01-01T11:47'),
#  numpy.datetime64('2001-01-01T11:48'),
#  numpy.datetime64('2001-01-01T11:49'),
#  numpy.datetime64('2001-01-01T11:50'),
#  numpy.datetime64('2001-01-01T11:51'),
#  numpy.datetime64('2001-01-01T11:52'),
#  numpy.datetime64('2001-01-01T11:53'),
#  numpy.datetime64('2001-01-01T11:54'),
#  numpy.datetime64('2001-01-01T11:55'),
#  numpy.datetime64('2001-01-01T11:56'),
#  numpy.datetime64('2001-01-01T11:57'),
#  numpy.datetime64('2001-01-01T11:58'),
#  numpy.datetime64('2001-01-01T11:59'),
#  numpy.datetime64('2001-01-01T12:00'),
#  numpy.datetime64('2001-01-01T12:01'),
#  numpy.datetime64('2001-01-01T12:02'),
#  numpy.datetime64('2001-01-01T12:03'),
#  numpy.datetime64('2001-01-01T12:04'),
#  numpy.datetime64('2001-01-01T12:05'),
#  numpy.datetime64('2001-01-01T12:06'),
#  numpy.datetime64('2001-01-01T12:07'),
#  numpy.datetime64('2001-01-01T12:08'),
#  numpy.datetime64('2001-01-01T12:09'),
#  numpy.datetime64('2001-01-01T12:10'),
#  numpy.datetime64('2001-01-01T12:11'),
#  numpy.datetime64('2001-01-01T12:12'),
#  numpy.datetime64('2001-01-01T12:13'),
#  numpy.datetime64('2001-01-01T12:14'),
#  numpy.datetime64('2001-01-01T12:15'),
#  numpy.datetime64('2001-01-01T12:16'),
#  numpy.datetime64('2001-01-01T12:17'),
#  numpy.datetime64('2001-01-01T12:18'),
#  numpy.datetime64('2001-01-01T12:19'),
#  numpy.datetime64('2001-01-01T12:20'),
#  numpy.datetime64('2001-01-01T12:21'),
#  numpy.datetime64('2001-01-01T12:22'),
#  numpy.datetime64('2001-01-01T12:23'),
#  numpy.datetime64('2001-01-01T12:24'),
#  numpy.datetime64('2001-01-01T12:25'),
#  numpy.datetime64('2001-01-01T12:26'),
#  numpy.datetime64('2001-01-01T12:27'),
#  numpy.datetime64('2001-01-01T12:28'),
#  numpy.datetime64('2001-01-01T12:29'),
#  numpy.datetime64('2001-01-01T12:30'),
#  numpy.datetime64('2001-01-01T12:31'),
#  numpy.datetime64('2001-01-01T12:32'),
#  numpy.datetime64('2001-01-01T12:33'),
#  numpy.datetime64('2001-01-01T12:34'),
#  numpy.datetime64('2001-01-01T12:35'),
#  numpy.datetime64('2001-01-01T12:36'),
#  numpy.datetime64('2001-01-01T12:37'),
#  numpy.datetime64('2001-01-01T12:38'),
#  numpy.datetime64('2001-01-01T12:39'),
#  numpy.datetime64('2001-01-01T12:40'),
#  numpy.datetime64('2001-01-01T12:41'),
#  numpy.datetime64('2001-01-01T12:42'),
#  numpy.datetime64('2001-01-01T12:43'),
#  numpy.datetime64('2001-01-01T12:44'),
#  numpy.datetime64('2001-01-01T12:45'),
#  numpy.datetime64('2001-01-01T12:46'),
#  numpy.datetime64('2001-01-01T12:47'),
#  numpy.datetime64('2001-01-01T12:48'),
#  numpy.datetime64('2001-01-01T12:49'),
#  numpy.datetime64('2001-01-01T12:50'),
#  numpy.datetime64('2001-01-01T12:51'),
#  numpy.datetime64('2001-01-01T12:52'),
#  numpy.datetime64('2001-01-01T12:53'),
#  numpy.datetime64('2001-01-01T12:54'),
#  numpy.datetime64('2001-01-01T12:55'),
#  numpy.datetime64('2001-01-01T12:56'),
#  numpy.datetime64('2001-01-01T12:57'),
#  numpy.datetime64('2001-01-01T12:58'),
#  numpy.datetime64('2001-01-01T12:59'),
#  numpy.datetime64('2001-01-01T13:00'),
#  numpy.datetime64('2001-01-01T13:01'),
#  numpy.datetime64('2001-01-01T13:02'),
#  numpy.datetime64('2001-01-01T13:03'),
#  numpy.datetime64('2001-01-01T13:04'),
#  numpy.datetime64('2001-01-01T13:05'),
#  numpy.datetime64('2001-01-01T13:06'),
#  numpy.datetime64('2001-01-01T13:07'),
#  numpy.datetime64('2001-01-01T13:08'),
#  numpy.datetime64('2001-01-01T13:09'),
#  numpy.datetime64('2001-01-01T13:10'),
#  numpy.datetime64('2001-01-01T13:11'),
#  numpy.datetime64('2001-01-01T13:12'),
#  numpy.datetime64('2001-01-01T13:13'),
#  numpy.datetime64('2001-01-01T13:14'),
#  numpy.datetime64('2001-01-01T13:15'),
#  numpy.datetime64('2001-01-01T13:16'),
#  numpy.datetime64('2001-01-01T13:17'),
#  numpy.datetime64('2001-01-01T13:18'),
#  numpy.datetime64('2001-01-01T13:19'),
#  numpy.datetime64('2001-01-01T13:20'),
#  numpy.datetime64('2001-01-01T13:21'),
#  numpy.datetime64('2001-01-01T13:22'),
#  numpy.datetime64('2001-01-01T13:23'),
#  numpy.datetime64('2001-01-01T13:24'),
#  numpy.datetime64('2001-01-01T13:25'),
#  numpy.datetime64('2001-01-01T13:26'),
#  numpy.datetime64('2001-01-01T13:27'),
#  numpy.datetime64('2001-01-01T13:28'),
#  numpy.datetime64('2001-01-01T13:29'),
#  numpy.datetime64('2001-01-01T13:30'),
#  numpy.datetime64('2001-01-01T13:31'),
#  numpy.datetime64('2001-01-01T13:32'),
#  numpy.datetime64('2001-01-01T13:33'),
#  numpy.datetime64('2001-01-01T13:34'),
#  numpy.datetime64('2001-01-01T13:35'),
#  numpy.datetime64('2001-01-01T13:36'),
#  numpy.datetime64('2001-01-01T13:37'),
#  numpy.datetime64('2001-01-01T13:38'),
#  numpy.datetime64('2001-01-01T13:39'),
#  numpy.datetime64('2001-01-01T13:40'),
#  numpy.datetime64('2001-01-01T13:41'),
#  numpy.datetime64('2001-01-01T13:42'),
#  numpy.datetime64('2001-01-01T13:43'),
#  numpy.datetime64('2001-01-01T13:44'),
#  numpy.datetime64('2001-01-01T13:45'),
#  numpy.datetime64('2001-01-01T13:46'),
#  numpy.datetime64('2001-01-01T13:47'),
#  numpy.datetime64('2001-01-01T13:48'),
#  numpy.datetime64('2001-01-01T13:49'),
#  numpy.datetime64('2001-01-01T13:50'),
#  numpy.datetime64('2001-01-01T13:51'),
#  numpy.datetime64('2001-01-01T13:52'),
#  numpy.datetime64('2001-01-01T13:53'),
#  numpy.datetime64('2001-01-01T13:54'),
#  numpy.datetime64('2001-01-01T13:55'),
#  numpy.datetime64('2001-01-01T13:56'),
#  numpy.datetime64('2001-01-01T13:57'),
#  numpy.datetime64('2001-01-01T13:58'),
#  numpy.datetime64('2001-01-01T13:59'),
#  numpy.datetime64('2001-01-01T14:00'),
#  numpy.datetime64('2001-01-01T14:01'),
#  numpy.datetime64('2001-01-01T14:02'),
#  numpy.datetime64('2001-01-01T14:03'),
#  numpy.datetime64('2001-01-01T14:04'),
#  numpy.datetime64('2001-01-01T14:05'),
#  numpy.datetime64('2001-01-01T14:06'),
#  numpy.datetime64('2001-01-01T14:07'),
#  numpy.datetime64('2001-01-01T14:08'),
#  numpy.datetime64('2001-01-01T14:09'),
#  numpy.datetime64('2001-01-01T14:10'),
#  numpy.datetime64('2001-01-01T14:11'),
#  numpy.datetime64('2001-01-01T14:12'),
#  numpy.datetime64('2001-01-01T14:13'),
#  numpy.datetime64('2001-01-01T14:14'),
#  numpy.datetime64('2001-01-01T14:15'),
#  numpy.datetime64('2001-01-01T14:16'),
#  numpy.datetime64('2001-01-01T14:17'),
#  numpy.datetime64('2001-01-01T14:18'),
#  numpy.datetime64('2001-01-01T14:19'),
#  numpy.datetime64('2001-01-01T14:20'),
#  numpy.datetime64('2001-01-01T14:21'),
#  numpy.datetime64('2001-01-01T14:22'),
#  numpy.datetime64('2001-01-01T14:23'),
#  numpy.datetime64('2001-01-01T14:24'),
#  numpy.datetime64('2001-01-01T14:25'),
#  numpy.datetime64('2001-01-01T14:26'),
#  numpy.datetime64('2001-01-01T14:27'),
#  numpy.datetime64('2001-01-01T14:28'),
#  numpy.datetime64('2001-01-01T14:29'),
#  numpy.datetime64('2001-01-01T14:30'),
#  numpy.datetime64('2001-01-01T14:31'),
#  numpy.datetime64('2001-01-01T14:32'),
#  numpy.datetime64('2001-01-01T14:33'),
#  numpy.datetime64('2001-01-01T14:34'),
#  numpy.datetime64('2001-01-01T14:35'),
#  numpy.datetime64('2001-01-01T14:36'),
#  numpy.datetime64('2001-01-01T14:37'),
#  numpy.datetime64('2001-01-01T14:38'),
#  numpy.datetime64('2001-01-01T14:39'),
#  numpy.datetime64('2001-01-01T14:40'),
#  numpy.datetime64('2001-01-01T14:41'),
#  numpy.datetime64('2001-01-01T14:42'),
#  numpy.datetime64('2001-01-01T14:43'),
#  numpy.datetime64('2001-01-01T14:44'),
#  numpy.datetime64('2001-01-01T14:45'),
#  numpy.datetime64('2001-01-01T14:46'),
#  numpy.datetime64('2001-01-01T14:47'),
#  numpy.datetime64('2001-01-01T14:48'),
#  numpy.datetime64('2001-01-01T14:49'),
#  numpy.datetime64('2001-01-01T14:50'),
#  numpy.datetime64('2001-01-01T14:51'),
#  numpy.datetime64('2001-01-01T14:52'),
#  numpy.datetime64('2001-01-01T14:53'),
#  numpy.datetime64('2001-01-01T14:54'),
#  numpy.datetime64('2001-01-01T14:55'),
#  numpy.datetime64('2001-01-01T14:56'),
#  numpy.datetime64('2001-01-01T14:57'),
#  numpy.datetime64('2001-01-01T14:58'),
#  numpy.datetime64('2001-01-01T14:59'),
#  numpy.datetime64('2001-01-01T15:00'),
#  numpy.datetime64('2001-01-01T15:01'),
#  numpy.datetime64('2001-01-01T15:02'),
#  numpy.datetime64('2001-01-01T15:03'),
#  numpy.datetime64('2001-01-01T15:04'),
#  numpy.datetime64('2001-01-01T15:05'),
#  numpy.datetime64('2001-01-01T15:06'),
#  numpy.datetime64('2001-01-01T15:07'),
#  numpy.datetime64('2001-01-01T15:08'),
#  numpy.datetime64('2001-01-01T15:09'),
#  numpy.datetime64('2001-01-01T15:10'),
#  numpy.datetime64('2001-01-01T15:11'),
#  numpy.datetime64('2001-01-01T15:12'),
#  numpy.datetime64('2001-01-01T15:13'),
#  numpy.datetime64('2001-01-01T15:14'),
#  numpy.datetime64('2001-01-01T15:15'),
#  numpy.datetime64('2001-01-01T15:16'),
#  numpy.datetime64('2001-01-01T15:17'),
#  numpy.datetime64('2001-01-01T15:18'),
#  numpy.datetime64('2001-01-01T15:19'),
#  numpy.datetime64('2001-01-01T15:20'),
#  numpy.datetime64('2001-01-01T15:21'),
#  numpy.datetime64('2001-01-01T15:22'),
#  numpy.datetime64('2001-01-01T15:23'),
#  numpy.datetime64('2001-01-01T15:24'),
#  numpy.datetime64('2001-01-01T15:25'),
#  numpy.datetime64('2001-01-01T15:26'),
#  numpy.datetime64('2001-01-01T15:27'),
#  numpy.datetime64('2001-01-01T15:28'),
#  numpy.datetime64('2001-01-01T15:29'),
#  numpy.datetime64('2001-01-01T15:30'),
#  numpy.datetime64('2001-01-01T15:31'),
#  numpy.datetime64('2001-01-01T15:32'),
#  numpy.datetime64('2001-01-01T15:33'),
#  numpy.datetime64('2001-01-01T15:34'),
#  numpy.datetime64('2001-01-01T15:35'),
#  numpy.datetime64('2001-01-01T15:36'),
#  numpy.datetime64('2001-01-01T15:37'),
#  numpy.datetime64('2001-01-01T15:38'),
#  numpy.datetime64('2001-01-01T15:39'),
#  numpy.datetime64('2001-01-01T15:40'),
#  numpy.datetime64('2001-01-01T15:41'),
#  numpy.datetime64('2001-01-01T15:42'),
#  numpy.datetime64('2001-01-01T15:43'),
#  numpy.datetime64('2001-01-01T15:44'),
#  numpy.datetime64('2001-01-01T15:45'),
#  numpy.datetime64('2001-01-01T15:46'),
#  numpy.datetime64('2001-01-01T15:47'),
#  numpy.datetime64('2001-01-01T15:48'),
#  numpy.datetime64('2001-01-01T15:49'),
#  numpy.datetime64('2001-01-01T15:50'),
#  numpy.datetime64('2001-01-01T15:51'),
#  numpy.datetime64('2001-01-01T15:52'),
#  numpy.datetime64('2001-01-01T15:53'),
#  numpy.datetime64('2001-01-01T15:54'),
#  numpy.datetime64('2001-01-01T15:55'),
#  numpy.datetime64('2001-01-01T15:56'),
#  numpy.datetime64('2001-01-01T15:57'),
#  numpy.datetime64('2001-01-01T15:58'),
#  numpy.datetime64('2001-01-01T15:59'),
#  numpy.datetime64('2001-01-01T16:00'),
#  numpy.datetime64('2001-01-01T16:01'),
#  numpy.datetime64('2001-01-01T16:02'),
#  numpy.datetime64('2001-01-01T16:03'),
#  numpy.datetime64('2001-01-01T16:04'),
#  numpy.datetime64('2001-01-01T16:05'),
#  numpy.datetime64('2001-01-01T16:06'),
#  numpy.datetime64('2001-01-01T16:07'),
#  numpy.datetime64('2001-01-01T16:08'),
#  numpy.datetime64('2001-01-01T16:09'),
#  numpy.datetime64('2001-01-01T16:10'),
#  numpy.datetime64('2001-01-01T16:11'),
#  numpy.datetime64('2001-01-01T16:12'),
#  numpy.datetime64('2001-01-01T16:13'),
#  numpy.datetime64('2001-01-01T16:14'),
#  numpy.datetime64('2001-01-01T16:15'),
#  numpy.datetime64('2001-01-01T16:16'),
#  numpy.datetime64('2001-01-01T16:17'),
#  numpy.datetime64('2001-01-01T16:18'),
#  numpy.datetime64('2001-01-01T16:19'),
#  numpy.datetime64('2001-01-01T16:20'),
#  numpy.datetime64('2001-01-01T16:21'),
#  numpy.datetime64('2001-01-01T16:22'),
#  numpy.datetime64('2001-01-01T16:23'),
#  numpy.datetime64('2001-01-01T16:24'),
#  numpy.datetime64('2001-01-01T16:25'),
#  numpy.datetime64('2001-01-01T16:26'),
#  numpy.datetime64('2001-01-01T16:27'),
#  numpy.datetime64('2001-01-01T16:28'),
#  numpy.datetime64('2001-01-01T16:29'),
#  numpy.datetime64('2001-01-01T16:30'),
#  numpy.datetime64('2001-01-01T16:31'),
#  numpy.datetime64('2001-01-01T16:32'),
#  numpy.datetime64('2001-01-01T16:33'),
#  numpy.datetime64('2001-01-01T16:34'),
#  numpy.datetime64('2001-01-01T16:35'),
#  numpy.datetime64('2001-01-01T16:36'),
#  numpy.datetime64('2001-01-01T16:37'),
#  numpy.datetime64('2001-01-01T16:38'),
#  numpy.datetime64('2001-01-01T16:39')]

# %% [markdown]
# This code creates a set of uniformly random values with the same amount of numbers as there are times

# %%
values= np.random.uniform(0, 1, size=len(times))
values
# Out:
# array([0.36302846, 0.48068809, 0.60583755, 0.83013175, 0.67957134,
#        0.10622056, 0.77949164, 0.67572403, 0.44229958, 0.89900184,
#        0.66379119, 0.81653315, 0.85361607, 0.63316249, 0.19700519,
#        0.04478003, 0.27538   , 0.30002331, 0.08689191, 0.00995677,
#        0.91901347, 0.03417401, 0.22279436, 0.3752653 , 0.51232948,
#        0.08367827, 0.13685564, 0.36151737, 0.94474315, 0.01724878,
#        0.41360739, 0.32590229, 0.54789281, 0.04707465, 0.94738807,
#        0.52090584, 0.25774416, 0.97892025, 0.84343163, 0.98220997,
#        0.92661405, 0.90778874, 0.86705176, 0.29535051, 0.73620275,
#        0.2024862 , 0.29305791, 0.98976022, 0.08512671, 0.67592091,
#        0.90137396, 0.08563477, 0.83147113, 0.24468133, 0.9580892 ,
#        0.11736836, 0.16972721, 0.5142989 , 0.93974718, 0.77541249,
#        0.91875566, 0.07264228, 0.97854753, 0.63718006, 0.21463974,
#        0.22612119, 0.11716228, 0.65218375, 0.92171436, 0.33842309,
#        0.28086044, 0.33023282, 0.98714875, 0.91087389, 0.24032551,
#        0.72508891, 0.91729282, 0.04391075, 0.72996085, 0.55492394,
#        0.70345664, 0.2507635 , 0.70830453, 0.41899751, 0.41221369,
#        0.44841777, 0.1638307 , 0.01000807, 0.05418186, 0.64084101,
#        0.63995708, 0.58630831, 0.75457727, 0.28074934, 0.5962603 ,
#        0.27601137, 0.9775476 , 0.59435429, 0.35090422, 0.56599495,
#        0.29505673, 0.0812222 , 0.00628245, 0.04742586, 0.98307872,
#        0.29909001, 0.76073128, 0.24697949, 0.9371606 , 0.04114078,
#        0.92333657, 0.64403699, 0.88665695, 0.83011397, 0.97997202,
#        0.9066037 , 0.31498391, 0.65961972, 0.4324433 , 0.93388006,
#        0.67624928, 0.82299956, 0.05749678, 0.04754707, 0.85643805,
#        0.50302343, 0.23371993, 0.63293495, 0.37446582, 0.73586811,
#        0.18411711, 0.61050855, 0.10313706, 0.21721542, 0.05091166,
#        0.91877661, 0.60696368, 0.70666784, 0.37233907, 0.77403945,
#        0.31843305, 0.64838112, 0.46439542, 0.65982566, 0.95244539,
#        0.56103437, 0.05265041, 0.65273218, 0.24500295, 0.04344154,
#        0.20579465, 0.42382764, 0.06251642, 0.32447752, 0.63300158,
#        0.87572825, 0.48135291, 0.71704653, 0.98142075, 0.46837563,
#        0.12428875, 0.28083522, 0.04165466, 0.82660403, 0.75572774])

# %% [markdown]
# next we create a dataframe using the from arrays function as our data are arrays

# %% [markdown]
# you will see how the column names are dictated by looking at the arguments

# %%
test= vx.from_arrays(time= times, x= values)
test
# Out:
# #    time              x
# 0    2001-01-01 00:00  0.36302845551731866
# 1    2001-01-01 00:01  0.48068808773515237
# 2    2001-01-01 00:02  0.6058375547894259
# 3    2001-01-01 00:03  0.8301317501829152
# 4    2001-01-01 00:04  0.6795713408417773
# ...  ...               ...
# 995  2001-01-01 16:35  0.12428875099199721
# 996  2001-01-01 16:36  0.2808352198565226
# 997  2001-01-01 16:37  0.041654655550825814
# 998  2001-01-01 16:38  0.8266040264540346
# 999  2001-01-01 16:39  0.7557277367646268

# %% [markdown]
# We are just to repeat this and create a second set of data with different dates

# %%
times= [np.datetime64('2002-01-01')+ np.timedelta64(i, 'm') for i in range(0, 1000, 1)]
values= np.random.uniform(10, 1000, size=len(times))
test2= vx.from_arrays(time= times, x= values)
test2
# Out:
# #    time              x
# 0    2002-01-01 00:00  399.11072769533445
# 1    2002-01-01 00:01  666.4738629578644
# 2    2002-01-01 00:02  502.5785908428068
# 3    2002-01-01 00:03  750.511866748664
# 4    2002-01-01 00:04  414.6906488415615
# ...  ...               ...
# 995  2002-01-01 16:35  17.158421722549203
# 996  2002-01-01 16:36  553.9676248891766
# 997  2002-01-01 16:37  507.25759836845174
# 998  2002-01-01 16:38  779.9544855894283
# 999  2002-01-01 16:39  138.64436934560635

# %% [markdown]
# Using the concat function we can combine these dataframes by putting them on top of each other

# %%
merged= vx.concat((test, test2))
merged
# Out:
# #      time              x
# 0      2001-01-01 00:00  0.36302845551731866
# 1      2001-01-01 00:01  0.48068808773515237
# 2      2001-01-01 00:02  0.6058375547894259
# 3      2001-01-01 00:03  0.8301317501829152
# 4      2001-01-01 00:04  0.6795713408417773
# ...    ...               ...
# 1,995  2002-01-01 16:35  17.158421722549203
# 1,996  2002-01-01 16:36  553.9676248891766
# 1,997  2002-01-01 16:37  507.25759836845174
# 1,998  2002-01-01 16:38  779.9544855894283
# 1,999  2002-01-01 16:39  138.64436934560635

# %% [markdown]
# # Method 3
# - We can also combine dataframes by putting them side by side
# ### First we create our dataframes again

# %%
times= [np.datetime64('2001-01-01')+ np.timedelta64(i, 'm') for i in range(0, 1000, 1)]
values= np.random.uniform(0, 1, size=len(times))
test= vx.from_arrays(time= times, x= values)
test
# Out:
# #    time              x
# 0    2001-01-01 00:00  0.4462293678354615
# 1    2001-01-01 00:01  0.11413991273486279
# 2    2001-01-01 00:02  0.5760627601826598
# 3    2001-01-01 00:03  0.3547569158623005
# 4    2001-01-01 00:04  0.18769153479775347
# ...  ...               ...
# 995  2001-01-01 16:35  0.6952589446719261
# 996  2001-01-01 16:36  0.36578376389287215
# 997  2001-01-01 16:37  0.4573732922284146
# 998  2001-01-01 16:38  0.7586315559586169
# 999  2001-01-01 16:39  0.047818430161501335

# %%
times= [np.datetime64('2012-01-01')+ np.timedelta64(i, 'm') for i in range(0, 1000, 1)]
values= np.random.uniform(10, 1000, size=len(times))
test2= vx.from_arrays(other_time= times, y= values)
test2
# Out:
# #    other_time        y
# 0    2012-01-01 00:00  461.53972682006406
# 1    2012-01-01 00:01  158.3823521811828
# 2    2012-01-01 00:02  228.01788085855276
# 3    2012-01-01 00:03  193.38242079461943
# 4    2012-01-01 00:04  563.9879462768581
# ...  ...               ...
# 995  2012-01-01 16:35  952.6635065687016
# 996  2012-01-01 16:36  162.09426143203962
# 997  2012-01-01 16:37  738.9953255581695
# 998  2012-01-01 16:38  709.5187397966887
# 999  2012-01-01 16:39  946.7647694648217

# %% [markdown]
# This next step will use the function join

# %%
merged= test.join(test2)
merged
# Out:
# #    time              x                     other_time        y
# 0    2001-01-01 00:00  0.4462293678354615    2012-01-01 00:00  461.53972682006406
# 1    2001-01-01 00:01  0.11413991273486279   2012-01-01 00:01  158.3823521811828
# 2    2001-01-01 00:02  0.5760627601826598    2012-01-01 00:02  228.01788085855276
# 3    2001-01-01 00:03  0.3547569158623005    2012-01-01 00:03  193.38242079461943
# 4    2001-01-01 00:04  0.18769153479775347   2012-01-01 00:04  563.9879462768581
# ...  ...               ...                   ...               ...
# 995  2001-01-01 16:35  0.6952589446719261    2012-01-01 16:35  952.6635065687016
# 996  2001-01-01 16:36  0.36578376389287215   2012-01-01 16:36  162.09426143203962
# 997  2001-01-01 16:37  0.4573732922284146    2012-01-01 16:37  738.9953255581695
# 998  2001-01-01 16:38  0.7586315559586169    2012-01-01 16:38  709.5187397966887
# 999  2001-01-01 16:39  0.047818430161501335  2012-01-01 16:39  946.7647694648217

# %% [markdown]
# # Method 4
# - We could combine dataframes where column is matching
# - for example if wanted to add IMF data to a dataframe we would it to be when the times match
# ###### For this we will use two dataframes one with data every 5 minutes and another with data every minute (a bit like omni)

# %%
times= [np.datetime64('2001-01-01')+ np.timedelta64(i, 'm') for i in range(0, 1000, 5)]
values= np.random.uniform(0, 1, size=len(times))
test= vx.from_arrays(time= times, x= values)
test
# Out:
# #    time              x
# 0    2001-01-01 00:00  0.787019399008618
# 1    2001-01-01 00:05  0.43253777958677464
# 2    2001-01-01 00:10  0.7162191112363049
# 3    2001-01-01 00:15  0.7734549016645054
# 4    2001-01-01 00:20  0.6153444507162812
# ...  ...               ...
# 195  2001-01-01 16:15  0.05343936690767037
# 196  2001-01-01 16:20  0.5717978688091387
# 197  2001-01-01 16:25  0.6376807101751409
# 198  2001-01-01 16:30  0.04244476578604639
# 199  2001-01-01 16:35  0.10195495477527916

# %%
times= [np.datetime64('2001-01-01')+ np.timedelta64(i, 'm') for i in range(0, 1000, 1)]
values= np.random.uniform(10, 1000, size=len(times))
test2= vx.from_arrays(time= times, y= values)
test2
# Out:
# #    time              y
# 0    2001-01-01 00:00  92.70972630200556
# 1    2001-01-01 00:01  238.8206593477314
# 2    2001-01-01 00:02  755.4694365424425
# 3    2001-01-01 00:03  320.3329881820038
# 4    2001-01-01 00:04  22.877598057914458
# ...  ...               ...
# 995  2001-01-01 16:35  831.2785855073384
# 996  2001-01-01 16:36  434.9227245903252
# 997  2001-01-01 16:37  742.4670230895985
# 998  2001-01-01 16:38  465.8041028535589
# 999  2001-01-01 16:39  720.8039238809705

# %%
merged= test.join(test2, on='time')
merged
# Out:
# #    time              x                    y
# 0    2001-01-01 00:00  0.787019399008618    92.70972630200556
# 1    2001-01-01 00:05  0.43253777958677464  922.6103064872744
# 2    2001-01-01 00:10  0.7162191112363049   526.5783155758223
# 3    2001-01-01 00:15  0.7734549016645054   243.67985816021854
# 4    2001-01-01 00:20  0.6153444507162812   422.8028701115951
# ...  ...               ...                  ...
# 195  2001-01-01 16:15  0.05343936690767037  724.0636433326515
# 196  2001-01-01 16:20  0.5717978688091387   24.508893282969396
# 197  2001-01-01 16:25  0.6376807101751409   62.63574761453365
# 198  2001-01-01 16:30  0.04244476578604639  759.4337004559831
# 199  2001-01-01 16:35  0.10195495477527916  831.2785855073384

# %% [markdown]
# # Method 5
# - We will probably not use this method very often but it can be useful
# - We will combine two dataframes side by side but add something to the end of the column names so we know which dataframe they came from (particularly useful when there are columns with the same name)
# - remember if you don't use the "on" argument to only add when they match then the dataframes must be the same length

# %%
times= [np.datetime64('2001-01-01')+ np.timedelta64(i, 'm') for i in range(0, 1000, 1)]
values= np.random.uniform(0, 1, size=len(times))
test= vx.from_arrays(time= times, x= values)
test
# Out:
# #    time              x
# 0    2001-01-01 00:00  0.7999463333341551
# 1    2001-01-01 00:01  0.8477467596203243
# 2    2001-01-01 00:02  0.22292138075123302
# 3    2001-01-01 00:03  0.3301459085945413
# 4    2001-01-01 00:04  0.7357475457107566
# ...  ...               ...
# 995  2001-01-01 16:35  0.0337238566093665
# 996  2001-01-01 16:36  0.4522829337212446
# 997  2001-01-01 16:37  0.18172618033635557
# 998  2001-01-01 16:38  0.523934221252812
# 999  2001-01-01 16:39  0.5076510783370994

# %%
times= [np.datetime64('2001-01-01')+ np.timedelta64(i, 'm') for i in range(0, 1000, 2)]
values= np.random.uniform(10, 1000, size=len(times))
test2= vx.from_arrays(time= times, x= values)
test2
# Out:
# #    time              x
# 0    2001-01-01 00:00  282.3706095296273
# 1    2001-01-01 00:02  535.6000625290404
# 2    2001-01-01 00:04  831.9225276783598
# 3    2001-01-01 00:06  705.8951318584124
# 4    2001-01-01 00:08  499.940756681852
# ...  ...               ...
# 495  2001-01-01 16:30  865.3398539739405
# 496  2001-01-01 16:32  325.6038577884796
# 497  2001-01-01 16:34  739.6097837557462
# 498  2001-01-01 16:36  302.5347792671054
# 499  2001-01-01 16:38  331.9886138888376

# %%
merged= test.join(test2, on='time', lsuffix='_1', rsuffix='_2')
merged
# Out:
